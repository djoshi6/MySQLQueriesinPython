# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Install packages
# !pip3 install pymysql                   
# !pip3 install plotly
# !pip3 install cufflinks
# Out:
# Requirement already satisfied: pymysql in c:\users\kf571hb\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: plotly in c:\users\kf571hb\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: cufflinks in c:\users\kf571hb\anaconda3\lib\site-packages (0.17.3)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from cufflinks) (7.22.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from cufflinks) (7.6.3)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\kf571hb\anaconda3\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\kf571hb\anaconda3\lib\site-packages (from cufflinks) (1.2.4)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\kf571hb\anaconda3\lib\site-packages (from cufflinks) (5.9.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from cufflinks) (1.15.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\kf571hb\anaconda3\lib\site-packages (from cufflinks) (52.0.0.post20210125)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\kf571hb\anaconda3\lib\site-packages (from cufflinks) (1.20.1)
# Requirement already satisfied: pygments in c:\users\kf571hb\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.8.1)
# Requirement already satisfied: backcall in c:\users\kf571hb\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: colorama in c:\users\kf571hb\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.17)
# Requirement already satisfied: jedi>=0.16 in c:\users\kf571hb\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.17.2)
# Requirement already satisfied: pickleshare in c:\users\kf571hb\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: decorator in c:\users\kf571hb\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.0.6)
# Requirement already satisfied: traitlets>=4.2 in c:\users\kf571hb\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\kf571hb\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (5.3.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.1)
# Requirement already satisfied: jupyter-client in c:\users\kf571hb\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\kf571hb\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: ipython-genutils in c:\users\kf571hb\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\kf571hb\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\kf571hb\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (20.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\kf571hb\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\kf571hb\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2021.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (8.0.1)
# Requirement already satisfied: wcwidth in c:\users\kf571hb\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\kf571hb\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.3.0)
# Requirement already satisfied: jinja2 in c:\users\kf571hb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: nbconvert in c:\users\kf571hb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\kf571hb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.9.4)
# Requirement already satisfied: argon2-cffi in c:\users\kf571hb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\kf571hb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (20.0.0)
# Requirement already satisfied: prometheus-client in c:\users\kf571hb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.10.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\kf571hb\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\kf571hb\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kf571hb\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.1.1)
# Requirement already satisfied: testpath in c:\users\kf571hb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\kf571hb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\kf571hb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.3)
# Requirement already satisfied: bleach in c:\users\kf571hb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\kf571hb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\kf571hb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\kf571hb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\kf571hb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\kf571hb\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\kf571hb\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.10)
# Requirement already satisfied: packaging in c:\users\kf571hb\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (20.9)
# Requirement already satisfied: webencodings in c:\users\kf571hb\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\kf571hb\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.4.7)

# %%
#import statements
import pymysql
import pandas as pd

# %%
#!/usr/bin/python3

# Open database connection
db = pymysql.connect(host="localhost",user="root",password="rootroot")


# prepare a cursor object using cursor() method
cursor = db.cursor()

# execute SQL query using execute() method.
cursor.execute("SELECT VERSION()")

# Fetch a single row using fetchone() method.
data = cursor.fetchone()

print ("Database version : %s " % data)

# disconnect from server
# db.close()
# Out:
# Database version : 8.0.29

# %%
# Create a function for easily querying data.
def qry(sql):

    # Open database connection
#     connection = pymysql.connect(host="localhost",user="root",password="rootroot")
    df = pd.read_sql(sql, db)

    # disconnect from server
#     connection.close()
    
    # return data.
    return df

# %% [markdown]
# # Part B (Individual): Manipulating, Categorizing, Sorting and Grouping & Summarizing Data

# %% [markdown]
# ### Question 1

# %%
# a) Show the list of databases.
sql = "SHOW DATABASES;"

df = qry(sql)
df
# Out:
#              Database
# 0       classicmodels
# 1  information_schema
# 2               mysql
# 3  performance_schema
# 4              sakila
# 5                 sys
# 6               world

# %%
# b) Select sakila database.

sql = "USE sakila;"

# df = qry(sql)
# df

try:
   # Execute the SQL command
   cursor.execute(sql)
    
   # Fetch all the rows in a list of lists.
   rows = cursor.fetchall()

except:
    print ("Error: unable to fetch data")

# %%
# c) Show all tables in the sakila database.

sql = "SHOW TABLES;"

df = qry(sql)
df
# Out:
#               Tables_in_sakila
# 0                        actor
# 1                   actor_info
# 2                      address
# 3                     category
# 4                         city
# 5                      country
# 6                     customer
# 7                customer_list
# 8                         film
# 9                   film_actor
# 10               film_category
# 11                   film_list
# 12                   film_text
# 13                   inventory
# 14                    language
# 15  nicer_but_slower_film_list
# 16                     payment
# 17                      rental
# 18      sales_by_film_category
# 19              sales_by_store
# 20                       staff
# 21                  staff_list
# 22                       store

# %%
# d) Show each of the columns along with their data types for the actor table.
sql = "describe actor;"

df = qry(sql)
df
# Out:
#          Field               Type Null  Key            Default  \
# 0     actor_id  smallint unsigned   NO  PRI               None
# 1   first_name        varchar(45)   NO                    None
# 2    last_name        varchar(45)   NO  MUL               None
# 3  last_update          timestamp   NO       CURRENT_TIMESTAMP
#
#                                            Extra
# 0                                 auto_increment
# 1
# 2
# 3  DEFAULT_GENERATED on update CURRENT_TIMESTAMP

# %%
# e) Show the total number of records in the actor table.
sql = "select count(*)\
    from actor;"

df = qry(sql)
df
# Out:
#    count(*)
# 0       200

# %%
# f) What is the first name and last name of all the actors in the actor table ?
sql = "select first_name, last_name\
    from actor;"

df = qry(sql)
df
# Out:
#     first_name     last_name
# 0     PENELOPE       GUINESS
# 1         NICK      WAHLBERG
# 2           ED         CHASE
# 3     JENNIFER         DAVIS
# 4       JOHNNY  LOLLOBRIGIDA
# ..         ...           ...
# 195       BELA        WALKEN
# 196      REESE          WEST
# 197       MARY        KEITEL
# 198      JULIA       FAWCETT
# 199      THORA        TEMPLE
#
# [200 rows x 2 columns]

# %%
# g) Insert your first name (in first name column) and middle initial ( in the last name column ) into the actors table.

sql = "INSERT INTO actor (first_name, last_name) \
        VALUES ('Joe', 'NMI');"

try:
   # Execute the SQL command
   cursor.execute(sql)
    
   # Fetch all the rows in a list of lists.
   rows = cursor.fetchall()

except:
    print ("Error: unable to fetch data")

# %%
# h) Update your middle initial with your last name (in last name column) in the actors table.
sql = "update actor\
        set last_name = 'Hu'\
        where last_name = 'NMI';"

try:
   # Execute the SQL command
   cursor.execute(sql)
    
   # Fetch all the rows in a list of lists.
   rows = cursor.fetchall()

except:
    print ("Error: unable to fetch data")

# %%
sql = "select *\
    from actor;"

df = qry(sql)
df
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
# 200       211        Joe            Hu 2022-07-15 12:53:19
#
# [201 rows x 4 columns]

# %%
# i) Delete the new record from the actor table where the first name and last name matches yours.
sql = "DELETE FROM actor WHERE actor_id = 211;"

try:
   # Execute the SQL command
   cursor.execute(sql)
    
   # Fetch all the rows in a list of lists.
   rows = cursor.fetchall()

except:
    print ("Error: unable to fetch data")

# %%
sql = "select *\
    from actor;"

df = qry(sql)
df
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
# j) Create a table payment_type with the following specifications and appropriate data types
# Table Name : “Payment_type”
# Primary Key: "payment_type_id”
# Column: “Type”
# Insert following rows in to the table:
# 1, “Credit Card” ; 2, “Cash”; 3, “Paypal” ; 4 , “Cheque”
sql = "create table 'Payment_type' (\
        'Type' varchar(50) not null,\
        primary key ('payment_type_id')\
        ) ENGINE=INNODB DEFAULT CHARSET=LATIN1;"

try:
   # Execute the SQL command
   cursor.execute(sql)
    
   # Fetch all the rows in a list of lists.
   rows = cursor.fetchall()

except:
    print ("Error: unable to fetch data")
# Out:
# Error: unable to fetch data

# %%
# k) Rename table payment_type to payment_types.
sql = "rename table payment_type to payment_types;"

# df = qry(sql)
# df

try:
   # Execute the SQL command
   cursor.execute(sql)
    
   # Fetch all the rows in a list of lists.
   rows = cursor.fetchall()

except:
    print ("Error: unable to fetch data")
# Out:
# Error: unable to fetch data

# %%
# l) Drop the table payment_types.

sql = "drop table payment_types;"

# df = qry(sql)
# df

try:
   # Execute the SQL command
   cursor.execute(sql)
    
   # Fetch all the rows in a list of lists.
   rows = cursor.fetchall()

except:
    print ("Error: unable to fetch data")
# Out:
# Error: unable to fetch data

# %% [markdown]
# ## QUESTION 2

# %%
# a) List all the movies ( title & description ) that are rated PG-13 ?
sql = "select *\
        from film\
        where rating = 'PG-13';"

df = qry(sql)
df
# Out:
#      film_id               title  \
# 0          7     AIRPLANE SIERRA
# 1          9       ALABAMA DEVIL
# 2         18       ALTER VICTORY
# 3         28         ANTHEM LUKE
# 4         33         APOLLO TEEN
# ..       ...                 ...
# 218      971        WHALE BIKINI
# 219      972     WHISPERER GIANT
# 220      990  WORLD LEATHERNECKS
# 221      993      WRONG BEHAVIOR
# 222      994       WYOMING STORM
#
#                                            description  release_year  \
# 0    A Touching Saga of a Hunter And a Butler who m...          2006
# 1    A Thoughtful Panorama of a Database Administra...          2006
# 2    A Thoughtful Drama of a Composer And a Feminis...          2006
# 3    A Touching Panorama of a Waitress And a Woman ...          2006
# 4    A Action-Packed Reflection of a Crocodile And ...          2006
# ..                                                 ...           ...
# 218  A Intrepid Story of a Pastry Chef And a Databa...          2006
# 219  A Intrepid Story of a Dentist And a Hunter who...          2006
# 220  A Unbelieveable Tale of a Pioneer And a Astron...          2006
# 221  A Emotional Saga of a Crocodile And a Sumo Wre...          2006
# 222  A Awe-Inspiring Panorama of a Robot And a Boat...          2006
#
#      language_id original_language_id  rental_duration  rental_rate  length  \
# 0              1                 None                6         4.99      62
# 1              1                 None                3         2.99     114
# 2              1                 None                6         0.99      57
# 3              1                 None                5         4.99      91
# 4              1                 None                5         2.99     153
# ..           ...                  ...              ...          ...     ...
# 218            1                 None                4         4.99     109
# 219            1                 None                4         4.99      59
# 220            1                 None                3         0.99     171
# 221            1                 None                6         2.99     178
# 222            1                 None                6         4.99     100
#
#      replacement_cost rating  \
# 0               28.99  PG-13
# 1               21.99  PG-13
# 2               27.99  PG-13
# 3               16.99  PG-13
# 4               15.99  PG-13
# ..                ...    ...
# 218             11.99  PG-13
# 219             24.99  PG-13
# 220             13.99  PG-13
# 221             10.99  PG-13
# 222             29.99  PG-13
#
#                                       special_features         last_update
# 0                              Trailers,Deleted Scenes 2006-02-15 05:03:42
# 1                              Trailers,Deleted Scenes 2006-02-15 05:03:42
# 2                           Trailers,Behind the Scenes 2006-02-15 05:03:42
# 3                     Deleted Scenes,Behind the Scenes 2006-02-15 05:03:42
# 4    Trailers,Commentaries,Deleted Scenes,Behind th... 2006-02-15 05:03:42
# ..                                                 ...                 ...
# 218      Commentaries,Deleted Scenes,Behind the Scenes 2006-02-15 05:03:42
# 219                            Trailers,Deleted Scenes 2006-02-15 05:03:42
# 220                         Trailers,Behind the Scenes 2006-02-15 05:03:42
# 221                         Trailers,Behind the Scenes 2006-02-15 05:03:42
# 222                                     Deleted Scenes 2006-02-15 05:03:42
#
# [223 rows x 13 columns]

# %%
# b) List all movies that are either PG OR PG-13 using IN operator ?
sql = "select *\
        from film\
        where rating in ('PG', 'PG-13');"

df = qry(sql)
df
# Out:
#      film_id               title  \
# 0          1    ACADEMY DINOSAUR
# 1          6        AGENT TRUMAN
# 2          7     AIRPLANE SIERRA
# 3          9       ALABAMA DEVIL
# 4         12      ALASKA PHANTOM
# ..       ...                 ...
# 412      987        WORDS HUNTER
# 413      990  WORLD LEATHERNECKS
# 414      991        WORST BANGER
# 415      993      WRONG BEHAVIOR
# 416      994       WYOMING STORM
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Intrepid Panorama of a Robot And a Boy who m...          2006
# 2    A Touching Saga of a Hunter And a Butler who m...          2006
# 3    A Thoughtful Panorama of a Database Administra...          2006
# 4    A Fanciful Saga of a Hunter And a Pastry Chef ...          2006
# ..                                                 ...           ...
# 412  A Action-Packed Reflection of a Composer And a...          2006
# 413  A Unbelieveable Tale of a Pioneer And a Astron...          2006
# 414  A Thrilling Drama of a Madman And a Dentist wh...          2006
# 415  A Emotional Saga of a Crocodile And a Sumo Wre...          2006
# 416  A Awe-Inspiring Panorama of a Robot And a Boat...          2006
#
#      language_id original_language_id  rental_duration  rental_rate  length  \
# 0              1                 None                6         0.99      86
# 1              1                 None                3         2.99     169
# 2              1                 None                6         4.99      62
# 3              1                 None                3         2.99     114
# 4              1                 None                6         0.99     136
# ..           ...                  ...              ...          ...     ...
# 412            1                 None                3         2.99     116
# 413            1                 None                3         0.99     171
# 414            1                 None                4         2.99     185
# 415            1                 None                6         2.99     178
# 416            1                 None                6         4.99     100
#
#      replacement_cost rating                      special_features  \
# 0               20.99     PG      Deleted Scenes,Behind the Scenes
# 1               17.99     PG                        Deleted Scenes
# 2               28.99  PG-13               Trailers,Deleted Scenes
# 3               21.99  PG-13               Trailers,Deleted Scenes
# 4               22.99     PG           Commentaries,Deleted Scenes
# ..                ...    ...                                   ...
# 412             13.99     PG  Trailers,Commentaries,Deleted Scenes
# 413             13.99  PG-13            Trailers,Behind the Scenes
# 414             26.99     PG      Deleted Scenes,Behind the Scenes
# 415             10.99  PG-13            Trailers,Behind the Scenes
# 416             29.99  PG-13                        Deleted Scenes
#
#             last_update
# 0   2006-02-15 05:03:42
# 1   2006-02-15 05:03:42
# 2   2006-02-15 05:03:42
# 3   2006-02-15 05:03:42
# 4   2006-02-15 05:03:42
# ..                  ...
# 412 2006-02-15 05:03:42
# 413 2006-02-15 05:03:42
# 414 2006-02-15 05:03:42
# 415 2006-02-15 05:03:42
# 416 2006-02-15 05:03:42
#
# [417 rows x 13 columns]

# %%
# c) Report all payments greater than and equal to 2$ and Less than equal to 7$ ?
# Note : write 2 separate queries conditional operator and BETWEEN keyword
sql = "select *\
        from payment\
        where amount >= 2 and amount < 7 ;"

df = qry(sql)
df
# Out:
#        payment_id  customer_id  staff_id  rental_id  amount  \
# 0               1            1         1       76.0    2.99
# 1               3            1         1     1185.0    5.99
# 2               6            1         1     1725.0    4.99
# 3               7            1         1     2308.0    4.99
# 4               9            1         1     3284.0    3.99
# ...           ...          ...       ...        ...     ...
# 10868       16042          599         2     9679.0    2.99
# 10869       16043          599         2    11522.0    3.99
# 10870       16045          599         1    14599.0    4.99
# 10871       16048          599         2    15719.0    2.99
# 10872       16049          599         2    15725.0    2.99
#
#              payment_date         last_update
# 0     2005-05-25 11:30:37 2006-02-15 22:12:30
# 1     2005-06-15 00:54:12 2006-02-15 22:12:30
# 2     2005-06-16 15:18:57 2006-02-15 22:12:30
# 3     2005-06-18 08:41:48 2006-02-15 22:12:30
# 4     2005-06-21 06:24:45 2006-02-15 22:12:30
# ...                   ...                 ...
# 10868 2005-07-31 06:41:19 2006-02-15 22:24:11
# 10869 2005-08-17 00:05:05 2006-02-15 22:24:11
# 10870 2005-08-21 17:43:42 2006-02-15 22:24:12
# 10871 2005-08-23 11:08:46 2006-02-15 22:24:13
# 10872 2005-08-23 11:25:00 2006-02-15 22:24:13
#
# [10873 rows x 7 columns]

# %%
sql = "select *\
        from payment\
        where amount between 2 and 7 ;"

df = qry(sql)
df
# Out:
#        payment_id  customer_id  staff_id  rental_id  amount  \
# 0               1            1         1       76.0    2.99
# 1               3            1         1     1185.0    5.99
# 2               6            1         1     1725.0    4.99
# 3               7            1         1     2308.0    4.99
# 4               9            1         1     3284.0    3.99
# ...           ...          ...       ...        ...     ...
# 10868       16042          599         2     9679.0    2.99
# 10869       16043          599         2    11522.0    3.99
# 10870       16045          599         1    14599.0    4.99
# 10871       16048          599         2    15719.0    2.99
# 10872       16049          599         2    15725.0    2.99
#
#              payment_date         last_update
# 0     2005-05-25 11:30:37 2006-02-15 22:12:30
# 1     2005-06-15 00:54:12 2006-02-15 22:12:30
# 2     2005-06-16 15:18:57 2006-02-15 22:12:30
# 3     2005-06-18 08:41:48 2006-02-15 22:12:30
# 4     2005-06-21 06:24:45 2006-02-15 22:12:30
# ...                   ...                 ...
# 10868 2005-07-31 06:41:19 2006-02-15 22:24:11
# 10869 2005-08-17 00:05:05 2006-02-15 22:24:11
# 10870 2005-08-21 17:43:42 2006-02-15 22:24:12
# 10871 2005-08-23 11:08:46 2006-02-15 22:24:13
# 10872 2005-08-23 11:25:00 2006-02-15 22:24:13
#
# [10873 rows x 7 columns]

# %%
# d) List all addresses that have phone number that contain digits 589. A separate query for phone numbers that start with 140, and a third query that ends with 589
# Note : write 3 different queries
sql = "select *\
        from address\
        where phone like '%589%';"

df = qry(sql)
df
# Out:
#    address_id                     address address2       district  city_id  \
# 0           4        1411 Lillydale Drive     None            QLD      576
# 1         153            782 Mosul Street           Massachusetts       94
# 2         333            1860 Taguig Loop               West Java      119
# 3         388        368 Hunuco Boulevard                  Namibe      360
# 4         492           185 Mannheim Lane               Stavropol      408
# 5         504  1 Valle de Santiago Avenue                  Apulia       93
#
#   postal_code         phone  \
# 0                6172235589
# 1       25545  885899703621
# 2       59550   38158430589
# 3       17165  106439158941
# 4       23661  589377568313
# 5       86208  465897838272
#
#                                             location         last_update
# 0  b'\x00\x00\x00\x00\x01\x01\x00\x00\x00[\r\xe44... 2014-09-25 22:30:09
# 1  b'\x00\x00\x00\x00\x01\x01\x00\x00\x00\xe9\xc4... 2014-09-25 22:33:46
# 2  b'\x00\x00\x00\x00\x01\x01\x00\x00\x00B\xac\xa... 2014-09-25 22:31:32
# 3  b'\x00\x00\x00\x00\x01\x01\x00\x00\x00\xb5\x85... 2014-09-25 22:30:03
# 4  b'\x00\x00\x00\x00\x01\x01\x00\x00\x003>\x82\x... 2014-09-25 22:32:56
# 5  b'\x00\x00\x00\x00\x01\x01\x00\x00\x00\xca\xfe... 2014-09-25 22:31:43

# %%
# A separate query for phone numbers that start with 140, and a third query that ends with 589
sql = "select *\
        from address\
        where phone like '140%';"

df = qry(sql)
df
# Out:
#    address_id            address address2 district  city_id postal_code  \
# 0           3  23 Workhaven Lane     None  Alberta      300
#
#          phone                                           location  \
# 0  14033335568  b'\x00\x00\x00\x00\x01\x01\x00\x00\x00\xcd\xc4...
#
#           last_update
# 0 2014-09-25 22:30:27

# %%
#a third query that ends with 589
sql = "select *\
        from address\
        where phone like '%589';"

df = qry(sql)
df
# Out:
#    address_id               address address2   district  city_id postal_code  \
# 0           4  1411 Lillydale Drive     None        QLD      576
# 1         333      1860 Taguig Loop           West Java      119       59550
#
#          phone                                           location  \
# 0   6172235589  b'\x00\x00\x00\x00\x01\x01\x00\x00\x00[\r\xe44...
# 1  38158430589  b'\x00\x00\x00\x00\x01\x01\x00\x00\x00B\xac\xa...
#
#           last_update
# 0 2014-09-25 22:30:09
# 1 2014-09-25 22:31:32

# %%
# e) List all staff members ( first name, last name, email ) whose password is NULL ?
sql = "select *\
        from staff\
        where password is null;"

df = qry(sql)
df
# Out:
#    staff_id first_name last_name  address_id picture  \
# 0         2        Jon  Stephens           4    None
#
#                           email  store_id  active username password  \
# 0  Jon.Stephens@sakilastaff.com         2       1      Jon     None
#
#           last_update
# 0 2006-02-15 03:57:16

# %%
# f) Select all films that have title names like ZOO and rental duration greater than or equal to 4
sql = "select *\
        from film\
        where title like '%ZOO%' and rental_duration >= 4;"

df = qry(sql)
df
# Out:
#    film_id                 title  \
# 0      568     MEMENTO ZOOLANDER
# 1      924  UNFORGIVEN ZOOLANDER
# 2      999     ZOOLANDER FICTION
#
#                                          description  release_year  \
# 0  A Touching Epistle of a Squirrel And a Explore...          2006
# 1  A Taut Epistle of a Monkey And a Sumo Wrestler...          2006
# 2  A Fateful Reflection of a Waitress And a Boat ...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                4         4.99      77
# 1            1                 None                7         0.99     129
# 2            1                 None                5         2.99     101
#
#    replacement_cost rating                         special_features  \
# 0             11.99  NC-17                        Behind the Scenes
# 1             15.99     PG  Trailers,Commentaries,Behind the Scenes
# 2             28.99      R                  Trailers,Deleted Scenes
#
#           last_update
# 0 2006-02-15 05:03:42
# 1 2006-02-15 05:03:42
# 2 2006-02-15 05:03:42

# %%
# g) What is the cost of renting the movie ACADEMY DINOSAUR for 2 weeks ?
# Note : use of column alias and watch for rental_duration value
sql = "select rental_rate * rental_duration as cost_of_renting\
        from film\
        where title like '%academy dinosaur%';"

df = qry(sql)
df
# Out:
#    cost_of_renting
# 0             5.94

# %%
# h) List all unique districts where the customers, staff, and stores are located
# Note : check for NOT NULL values
sql = "select distinct district\
        from address\
        where district is not null;"

df = qry(sql)
df
# Out:
#         district
# 0        Alberta
# 1            QLD
# 2       Nagasaki
# 3     California
# 4         Attika
# ..           ...
# 373    al-Manama
# 374         Fejr
# 375  West Greece
# 376        Piura
# 377         Vaud
#
# [378 rows x 1 columns]

# %%
# i) List the top 10 newest customers across all stores based on customer_id
sql = "select *\
        from customer \
        order by customer_id desc\
        limit 10;"

df = qry(sql)
df
# Out:
#    customer_id  store_id first_name  last_name  \
# 0          599         2     AUSTIN    CINTRON
# 1          598         1       WADE   DELVALLE
# 2          597         1    FREDDIE     DUGGAN
# 3          596         1    ENRIQUE   FORSYTHE
# 4          595         1   TERRENCE  GUNDERSON
# 5          594         1    EDUARDO      HIATT
# 6          593         2       RENE  MCALISTER
# 7          592         1   TERRANCE      ROUSH
# 8          591         1       KENT  ARSENAULT
# 9          590         2       SETH     HANNON
#
#                                    email  address_id  active  \
# 0      AUSTIN.CINTRON@sakilacustomer.org         605       1
# 1       WADE.DELVALLE@sakilacustomer.org         604       1
# 2      FREDDIE.DUGGAN@sakilacustomer.org         603       1
# 3    ENRIQUE.FORSYTHE@sakilacustomer.org         602       1
# 4  TERRENCE.GUNDERSON@sakilacustomer.org         601       1
# 5       EDUARDO.HIATT@sakilacustomer.org         600       1
# 6      RENE.MCALISTER@sakilacustomer.org         599       1
# 7      TERRANCE.ROUSH@sakilacustomer.org         598       0
# 8      KENT.ARSENAULT@sakilacustomer.org         597       1
# 9         SETH.HANNON@sakilacustomer.org         596       1
#
#           create_date         last_update
# 0 2006-02-14 22:04:37 2006-02-15 04:57:20
# 1 2006-02-14 22:04:37 2006-02-15 04:57:20
# 2 2006-02-14 22:04:37 2006-02-15 04:57:20
# 3 2006-02-14 22:04:37 2006-02-15 04:57:20
# 4 2006-02-14 22:04:37 2006-02-15 04:57:20
# 5 2006-02-14 22:04:37 2006-02-15 04:57:20
# 6 2006-02-14 22:04:37 2006-02-15 04:57:20
# 7 2006-02-14 22:04:37 2006-02-15 04:57:20
# 8 2006-02-14 22:04:37 2006-02-15 04:57:20
# 9 2006-02-14 22:04:37 2006-02-15 04:57:20

# %% [markdown]
# ## QUESTION 3

# %%
# a) Show total number of movies
sql = "select count(film_id)\
        from film;"

df = qry(sql)
df
# Out:
#    count(film_id)
# 0            1000

# %%
# b) What is the minimum payment received and max payment received across all transactions ?
sql = "select min(amount), max(amount)\
        from payment;"

df = qry(sql)
df
# Out:
#    min(amount)  max(amount)
# 0          0.0        11.99

# %%
# c) Number of customers that rented movies between Feb-2005 & May-2005 ( based on paymentDate ).
sql = "select count(payment_id)\
        from payment\
        where payment_date between '2005-02-01' and '2005-05-31';"

df = qry(sql)
df
# Out:
#    count(payment_id)
# 0                994

# %%
# d) List all movies where replacement_cost is greater than 15$ or rental_duration is between 6 & 10 days
sql = "select *\
        from film\
        where replacement_cost > 15 or (rental_duration between 6 and 10);"

df = qry(sql)
df
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          3   ADAPTATION HOLES
# 2          4   AFFAIR PREJUDICE
# 3          5        AFRICAN EGG
# 4          6       AGENT TRUMAN
# ..       ...                ...
# 814      994      WYOMING STORM
# 815      996     YOUNG LANGUAGE
# 816      998       ZHIVAGO CORE
# 817      999  ZOOLANDER FICTION
# 818     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Reflection of a Lumberjack And a ...          2006
# 2    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 3    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# 4    A Intrepid Panorama of a Robot And a Boy who m...          2006
# ..                                                 ...           ...
# 814  A Awe-Inspiring Panorama of a Robot And a Boat...          2006
# 815  A Unbelieveable Yarn of a Boat And a Database ...          2006
# 816  A Fateful Yarn of a Composer And a Man who mus...          2006
# 817  A Fateful Reflection of a Waitress And a Boat ...          2006
# 818  A Intrepid Panorama of a Mad Scientist And a B...          2006
#
#      language_id original_language_id  rental_duration  rental_rate  length  \
# 0              1                 None                6         0.99      86
# 1              1                 None                7         2.99      50
# 2              1                 None                5         2.99     117
# 3              1                 None                6         2.99     130
# 4              1                 None                3         2.99     169
# ..           ...                  ...              ...          ...     ...
# 814            1                 None                6         4.99     100
# 815            1                 None                6         0.99     183
# 816            1                 None                6         0.99     105
# 817            1                 None                5         2.99     101
# 818            1                 None                3         4.99      50
#
#      replacement_cost rating                         special_features  \
# 0               20.99     PG         Deleted Scenes,Behind the Scenes
# 1               18.99  NC-17                  Trailers,Deleted Scenes
# 2               26.99      G           Commentaries,Behind the Scenes
# 3               22.99      G                           Deleted Scenes
# 4               17.99     PG                           Deleted Scenes
# ..                ...    ...                                      ...
# 814             29.99  PG-13                           Deleted Scenes
# 815              9.99      G               Trailers,Behind the Scenes
# 816             10.99  NC-17                           Deleted Scenes
# 817             28.99      R                  Trailers,Deleted Scenes
# 818             18.99  NC-17  Trailers,Commentaries,Behind the Scenes
#
#             last_update
# 0   2006-02-15 05:03:42
# 1   2006-02-15 05:03:42
# 2   2006-02-15 05:03:42
# 3   2006-02-15 05:03:42
# 4   2006-02-15 05:03:42
# ..                  ...
# 814 2006-02-15 05:03:42
# 815 2006-02-15 05:03:42
# 816 2006-02-15 05:03:42
# 817 2006-02-15 05:03:42
# 818 2006-02-15 05:03:42
#
# [819 rows x 13 columns]

# %%
# e) What is the total amount spent by customers for movies in the year 2005 ?
sql = "select sum(amount)\
        from payment\
        where payment_date between '2005-01-01' and '2005-12-31';"

df = qry(sql)
df
# Out:
#    sum(amount)
# 0     66902.33

# %%
# f) What is the average replacement cost across all movies ?
sql = "select avg(replacement_cost)\
        from film;"

df = qry(sql)
df
# Out:
#    avg(replacement_cost)
# 0                 19.984

# %%
# g) What is the standard deviation of rental rate across all movies ?
sql = "select std(rental_rate)\
        from film;"

df = qry(sql)
df
# Out:
#    std(rental_rate)
# 0           1.64557

# %%
# h) What is the midrange of the rental duration for all movies
sql = "select (max(rental_duration) + min(rental_duration)) / 2 as midRange\
        from film;"

df = qry(sql)
df
# Out:
#    midRange
# 0       5.0

# %% [markdown]
# ## QUESTION 4

# %%
# a) Customers sorted by first Name and last name in ascending order.
sql = "select *\
        from customer\
        order by (first_name and last_name) asc;"

df = qry(sql)
df
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  active  \
# 0            MARY.SMITH@sakilacustomer.org           5       1
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3         BARBARA.JONES@sakilacustomer.org           8       1
# 4       ELIZABETH.BROWN@sakilacustomer.org           9       1
# ..                                     ...         ...     ...
# 594  TERRENCE.GUNDERSON@sakilacustomer.org         601       1
# 595    ENRIQUE.FORSYTHE@sakilacustomer.org         602       1
# 596      FREDDIE.DUGGAN@sakilacustomer.org         603       1
# 597       WADE.DELVALLE@sakilacustomer.org         604       1
# 598      AUSTIN.CINTRON@sakilacustomer.org         605       1
#
#             create_date         last_update
# 0   2006-02-14 22:04:36 2006-02-15 04:57:20
# 1   2006-02-14 22:04:36 2006-02-15 04:57:20
# 2   2006-02-14 22:04:36 2006-02-15 04:57:20
# 3   2006-02-14 22:04:36 2006-02-15 04:57:20
# 4   2006-02-14 22:04:36 2006-02-15 04:57:20
# ..                  ...                 ...
# 594 2006-02-14 22:04:37 2006-02-15 04:57:20
# 595 2006-02-14 22:04:37 2006-02-15 04:57:20
# 596 2006-02-14 22:04:37 2006-02-15 04:57:20
# 597 2006-02-14 22:04:37 2006-02-15 04:57:20
# 598 2006-02-14 22:04:37 2006-02-15 04:57:20
#
# [599 rows x 9 columns]

# %%
# b) Count of movies that are either G/NC-17/PG-13/PG/R grouped by rating.
sql = "select rating, count(film_id)\
        from film\
        group by 1\
        having rating in ('G','NC-17','PG-13','R');"

df = qry(sql)
df
# Out:
#   rating  count(film_id)
# 0      G             178
# 1  NC-17             210
# 2  PG-13             223
# 3      R             195

# %%
# c) Number of addresses in each district.
sql = "select district, count(address_id)\
        from address\
        group by 1;"

df = qry(sql)
df
# Out:
#         district  count(address_id)
# 0        Alberta                  2
# 1            QLD                  2
# 2       Nagasaki                  1
# 3     California                  9
# 4         Attika                  1
# ..           ...                ...
# 373    al-Manama                  1
# 374         Fejr                  1
# 375  West Greece                  1
# 376        Piura                  1
# 377         Vaud                  1
#
# [378 rows x 2 columns]

# %%
# d) Find the movies where rental rate is greater than 1$ and order result set by descending order.
sql = "select *\
        from film\
        where rental_rate > 1\
        order by rental_rate desc;"

df = qry(sql)
df
# Out:
#      film_id              title  \
# 0          2     ACE GOLDFINGER
# 1          7    AIRPLANE SIERRA
# 2          8    AIRPORT POLLOCK
# 3         10   ALADDIN CALENDAR
# 4         13        ALI FOREVER
# ..       ...                ...
# 654      987       WORDS HUNTER
# 655      988      WORKER TARZAN
# 656      991       WORST BANGER
# 657      993     WRONG BEHAVIOR
# 658      999  ZOOLANDER FICTION
#
#                                            description  release_year  \
# 0    A Astounding Epistle of a Database Administrat...          2006
# 1    A Touching Saga of a Hunter And a Butler who m...          2006
# 2    A Epic Tale of a Moose And a Girl who must Con...          2006
# 3    A Action-Packed Tale of a Man And a Lumberjack...          2006
# 4    A Action-Packed Drama of a Dentist And a Croco...          2006
# ..                                                 ...           ...
# 654  A Action-Packed Reflection of a Composer And a...          2006
# 655  A Action-Packed Yarn of a Secret Agent And a T...          2006
# 656  A Thrilling Drama of a Madman And a Dentist wh...          2006
# 657  A Emotional Saga of a Crocodile And a Sumo Wre...          2006
# 658  A Fateful Reflection of a Waitress And a Boat ...          2006
#
#      language_id original_language_id  rental_duration  rental_rate  length  \
# 0              1                 None                3         4.99      48
# 1              1                 None                6         4.99      62
# 2              1                 None                6         4.99      54
# 3              1                 None                6         4.99      63
# 4              1                 None                4         4.99     150
# ..           ...                  ...              ...          ...     ...
# 654            1                 None                3         2.99     116
# 655            1                 None                7         2.99     139
# 656            1                 None                4         2.99     185
# 657            1                 None                6         2.99     178
# 658            1                 None                5         2.99     101
#
#      replacement_cost rating                         special_features  \
# 0               12.99      G                  Trailers,Deleted Scenes
# 1               28.99  PG-13                  Trailers,Deleted Scenes
# 2               15.99      R                                 Trailers
# 3               24.99  NC-17                  Trailers,Deleted Scenes
# 4               21.99     PG         Deleted Scenes,Behind the Scenes
# ..                ...    ...                                      ...
# 654             13.99     PG     Trailers,Commentaries,Deleted Scenes
# 655             26.99      R  Trailers,Commentaries,Behind the Scenes
# 656             26.99     PG         Deleted Scenes,Behind the Scenes
# 657             10.99  PG-13               Trailers,Behind the Scenes
# 658             28.99      R                  Trailers,Deleted Scenes
#
#             last_update
# 0   2006-02-15 05:03:42
# 1   2006-02-15 05:03:42
# 2   2006-02-15 05:03:42
# 3   2006-02-15 05:03:42
# 4   2006-02-15 05:03:42
# ..                  ...
# 654 2006-02-15 05:03:42
# 655 2006-02-15 05:03:42
# 656 2006-02-15 05:03:42
# 657 2006-02-15 05:03:42
# 658 2006-02-15 05:03:42
#
# [659 rows x 13 columns]

# %%
# e) Top 2 movies that are rated R with the highest replacement cost ?
sql = "select *\
        from film\
        where rating in ('R')\
        order by replacement_cost desc\
        limit 2;"

df = qry(sql)
df
# Out:
#    film_id                title  \
# 0      138  CHARIOTS CONSPIRACY
# 1      525     LOATHING LEGALLY
#
#                                          description  release_year  \
# 0  A Unbelieveable Epistle of a Robot And a Husba...          2006
# 1  A Boring Epistle of a Pioneer And a Mad Scient...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                5         2.99      71
# 1            1                 None                4         0.99     140
#
#    replacement_cost rating                  special_features  \
# 0             29.99      R  Deleted Scenes,Behind the Scenes
# 1             29.99      R                    Deleted Scenes
#
#           last_update
# 0 2006-02-15 05:03:42
# 1 2006-02-15 05:03:42

# %%
# f) Find the most frequently occurring (mode) rental rate across products.
sql = "select rental_rate as mode, title\
        from film\
        group by 1,2\
        order by count(1) desc\
        limit 1;"

df = qry(sql)
df
# Out:
#    mode             title
# 0  0.99  ACADEMY DINOSAUR

# %%
# g) Find the 2 longest movies with movie length greater than 50mins and which has commentaries as a special features.
sql = "select *\
        from film\
        where length > 50 and special_features like ('%commentaries%');"

df = qry(sql)
df
# Out:
#      film_id                title  \
# 0          4     AFFAIR PREJUDICE
# 1         11      ALAMO VIDEOTAPE
# 2         12       ALASKA PHANTOM
# 3         16      ALLEY EVOLUTION
# 4         19         AMADEUS HOLY
# ..       ...                  ...
# 513      987         WORDS HUNTER
# 514      988        WORKER TARZAN
# 515      989  WORKING MICROCOSMOS
# 516      992           WRATH MILE
# 517      995          YENTL IDAHO
#
#                                            description  release_year  \
# 0    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 1    A Boring Epistle of a Butler And a Cat who mus...          2006
# 2    A Fanciful Saga of a Hunter And a Pastry Chef ...          2006
# 3    A Fast-Paced Drama of a Robot And a Composer w...          2006
# 4    A Emotional Display of a Pioneer And a Technic...          2006
# ..                                                 ...           ...
# 513  A Action-Packed Reflection of a Composer And a...          2006
# 514  A Action-Packed Yarn of a Secret Agent And a T...          2006
# 515  A Stunning Epistle of a Dentist And a Dog who ...          2006
# 516  A Intrepid Reflection of a Technical Writer An...          2006
# 517  A Amazing Display of a Robot And a Astronaut w...          2006
#
#      language_id original_language_id  rental_duration  rental_rate  length  \
# 0              1                 None                5         2.99     117
# 1              1                 None                6         0.99     126
# 2              1                 None                6         0.99     136
# 3              1                 None                6         2.99     180
# 4              1                 None                6         0.99     113
# ..           ...                  ...              ...          ...     ...
# 513            1                 None                3         2.99     116
# 514            1                 None                7         2.99     139
# 515            1                 None                4         4.99      74
# 516            1                 None                5         0.99     176
# 517            1                 None                5         4.99      86
#
#      replacement_cost rating                               special_features  \
# 0               26.99      G                 Commentaries,Behind the Scenes
# 1               16.99      G                 Commentaries,Behind the Scenes
# 2               22.99     PG                    Commentaries,Deleted Scenes
# 3               23.99  NC-17                          Trailers,Commentaries
# 4               20.99     PG  Commentaries,Deleted Scenes,Behind the Scenes
# ..                ...    ...                                            ...
# 513             13.99     PG           Trailers,Commentaries,Deleted Scenes
# 514             26.99      R        Trailers,Commentaries,Behind the Scenes
# 515             22.99      R                    Commentaries,Deleted Scenes
# 516             17.99  NC-17                          Trailers,Commentaries
# 517             11.99      R           Trailers,Commentaries,Deleted Scenes
#
#             last_update
# 0   2006-02-15 05:03:42
# 1   2006-02-15 05:03:42
# 2   2006-02-15 05:03:42
# 3   2006-02-15 05:03:42
# 4   2006-02-15 05:03:42
# ..                  ...
# 513 2006-02-15 05:03:42
# 514 2006-02-15 05:03:42
# 515 2006-02-15 05:03:42
# 516 2006-02-15 05:03:42
# 517 2006-02-15 05:03:42
#
# [518 rows x 13 columns]

# %%
# h) List the years which has more than 2 movies released.
sql = "select release_year, count(film_id)\
        from film\
        group by 1\
        having count(film_id) > 2;"

df = qry(sql)
df
# Out:
#    release_year  count(film_id)
# 0          2006            1000
